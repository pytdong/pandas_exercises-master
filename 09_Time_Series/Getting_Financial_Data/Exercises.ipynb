# %% [markdown]
# # Getting Financial Data - Pandas Datareader

# %% [markdown]
# ### Introduction:
#
# This time you will get data from a website.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import pandas_datareader as pdr # 一个专门用于经济和金融数据读取的api库
import datetime

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is).

# %%
start_time = datetime.date(2015,1,1)
end_time = datetime.date.today()

# %% [markdown]
# ### Step 3. Get an API key for one of the APIs that are supported by Pandas Datareader, preferably for AlphaVantage.
#
# If you do not have an API key for any of the supported APIs, it is easiest to get one for [AlphaVantage](https://www.alphavantage.co/support/#api-key). (Note that the API key is shown directly after the signup. You do *not* receive it via e-mail.)
#
# (For a full list of the APIs that are supported by Pandas Datareader, [see here](https://pydata.github.io/pandas-datareader/readers/index.html). As the APIs are provided by third parties, this list may change.)

# %% [markdown]
# ### Step 4. Use Pandas Datarader to read the daily time series for the Apple stock (ticker symbol AAPL) between 01/01/2015 and today, assign it to df_apple and print it.

# %%
df_apple = pdr.data.get_data_stooq('AAPL',start=start_time,end=end_time)
df_apple.head()
# Out:
#                Open     High       Low    Close      Volume
# Date
# 2023-08-03  191.570  192.370  190.6900  191.170  62243282.0
# 2023-08-02  195.040  195.180  191.8507  192.580  50389327.0
# 2023-08-01  196.235  196.730  195.2800  195.605  35281426.0
# 2023-07-31  196.060  196.490  195.2600  196.450  38824113.0
# 2023-07-28  194.670  196.626  194.1400  195.830  48291443.0

# %% [markdown]
# ### Step 5. Add a new column "stock" to the dataframe and add the ticker symbol

# %%
df_apple['stock'] = 'AAPL'
df_apple.head()
# Out:
#                Open     High       Low    Close      Volume stock
# Date
# 2023-08-03  191.570  192.370  190.6900  191.170  62243282.0  AAPL
# 2023-08-02  195.040  195.180  191.8507  192.580  50389327.0  AAPL
# 2023-08-01  196.235  196.730  195.2800  195.605  35281426.0  AAPL
# 2023-07-31  196.060  196.490  195.2600  196.450  38824113.0  AAPL
# 2023-07-28  194.670  196.626  194.1400  195.830  48291443.0  AAPL

# %% [markdown]
# ### Step 6. Repeat the two previous steps for a few other stocks, always creating a new dataframe: Tesla, IBM and Microsoft. (Ticker symbols TSLA, IBM and MSFT.)

# %%
df_IBM = pdr.data.get_data_stooq('IBM',start=start_time,end=end_time)
df_Microsoft = pdr.data.get_data_stooq('MSFT',start=start_time,end=end_time)
df_Tesla = pdr.data.get_data_stooq('TSLA',start=start_time,end=end_time)

df_Tesla['stock'] = 'TSLA'
df_IBM['stock'] = 'IBM'
df_Microsoft['stock'] = 'MSFT'

# %% [markdown]
# ### Step 7. Combine the four separate dataFrames into one combined dataFrame df that holds the information for all four stocks

# %%
df = pd.concat([df_apple,df_Tesla,df_IBM,df_Microsoft],axis=0)
df
# Out:
#                 Open      High       Low     Close        Volume stock
# Date
# 2023-08-03  191.5700  192.3700  190.6900  191.1700  6.224328e+07  AAPL
# 2023-08-02  195.0400  195.1800  191.8507  192.5800  5.038933e+07  AAPL
# 2023-08-01  196.2350  196.7300  195.2800  195.6050  3.528143e+07  AAPL
# 2023-07-31  196.0600  196.4900  195.2600  196.4500  3.882411e+07  AAPL
# 2023-07-28  194.6700  196.6260  194.1400  195.8300  4.829144e+07  AAPL
# ...              ...       ...       ...       ...           ...   ...
# 2015-01-08   40.8036   41.6754   40.7759   41.5383  3.396421e+07  MSFT
# 2015-01-07   40.1306   40.5505   39.7037   40.3490  3.335749e+07  MSFT
# 2015-01-06   40.4790   40.8036   39.7494   39.8406  4.175715e+07  MSFT
# 2015-01-05   40.4701   40.7848   40.3658   40.4353  4.545445e+07  MSFT
# 2015-01-02   40.7242   41.3874   40.6179   40.8126  3.197669e+07  MSFT
#
# [8644 rows x 6 columns]

# %% [markdown]
# ### Step 8. Shift the stock column into the index (making it a multi-level index consisting of the ticker symbol and the date).

# %%
df.set_index(keys='stock',append=True,inplace=True)
df
# Out:
#                       Open      High       Low     Close        Volume
# Date       stock
# 2023-08-03 AAPL   191.5700  192.3700  190.6900  191.1700  6.224328e+07
# 2023-08-02 AAPL   195.0400  195.1800  191.8507  192.5800  5.038933e+07
# 2023-08-01 AAPL   196.2350  196.7300  195.2800  195.6050  3.528143e+07
# 2023-07-31 AAPL   196.0600  196.4900  195.2600  196.4500  3.882411e+07
# 2023-07-28 AAPL   194.6700  196.6260  194.1400  195.8300  4.829144e+07
# ...                    ...       ...       ...       ...           ...
# 2015-01-08 MSFT    40.8036   41.6754   40.7759   41.5383  3.396421e+07
# 2015-01-07 MSFT    40.1306   40.5505   39.7037   40.3490  3.335749e+07
# 2015-01-06 MSFT    40.4790   40.8036   39.7494   39.8406  4.175715e+07
# 2015-01-05 MSFT    40.4701   40.7848   40.3658   40.4353  4.545445e+07
# 2015-01-02 MSFT    40.7242   41.3874   40.6179   40.8126  3.197669e+07
#
# [8644 rows x 5 columns]

# %% [markdown]
# ### Step 7. Create a dataFrame called vol, with the volume values.

# %%
vol = pd.DataFrame(df.Volume)
vol
# Out:
#                         Volume
# Date       stock
# 2023-08-03 AAPL   6.224328e+07
# 2023-08-02 AAPL   5.038933e+07
# 2023-08-01 AAPL   3.528143e+07
# 2023-07-31 AAPL   3.882411e+07
# 2023-07-28 AAPL   4.829144e+07
# ...                        ...
# 2015-01-08 MSFT   3.396421e+07
# 2015-01-07 MSFT   3.335749e+07
# 2015-01-06 MSFT   4.175715e+07
# 2015-01-05 MSFT   4.545445e+07
# 2015-01-02 MSFT   3.197669e+07
#
# [8644 rows x 1 columns]

# %% [markdown]
# ### Step 8. Follow the previous step and aggregate the data of volume to weekly.
# Hint: Be careful to not sum data from the same week of 2015 and other years.

# %%
a = vol.resample('W',level='Date').sum()
a.groupby('stock')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 2
#       1 a = vol.resample('W',level='Date').sum()
# ----> 2 a.groupby('stock')
#
# File D:\Users\strength660\anaconda3\lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# ...

# %% [markdown]
# ### Step 9. Follow the previous step and find all the volume traded in the year of 2015
